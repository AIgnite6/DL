# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('commodities.csv')

# Check basic info of the dataset
print("Basic Information of the Dataset:")
df.info()
# Out:
# Basic Information of the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4191946 entries, 0 to 4191945
# Data columns (total 22 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   ROWID                                          int64
#  1   Country                                        object
#  2   State LGD Code                                 int64
#  3   State                                          object
#  4   District LGD Code                              int64
#  5   District                                       object
#  6   Market Name                                    object
#  7   Commodity Name                                 object
#  8   Variety of commodities                         object
#  9   Grade standard of commodity                    object
#  10  Minimum price for the commodity in the market  float64
# ...

# %%
# Check for missing values
print("\nMissing Values in the Dataset:")
print(df.isnull().sum())
# Out:
# Missing Values in the Dataset:
# ROWID                                            0
# Country                                          0
# State LGD Code                                   0
# State                                            0
# District LGD Code                                0
# District                                         0
# Market Name                                      0
# Commodity Name                                   0
# Variety of commodities                           0
# Grade standard of commodity                      0
# Minimum price for the commodity in the market    0
# Maximum price for the commodity in the market    0
# Modal price for the commodity                    0
# SourceCalendarDay                                0
# SourceMonth                                      0
# SourceYear                                       0
# YearCode                                         0
# Year                                             0
# ...

# %%
# Show basic statistics
print("\nStatistical Summary of the Dataset:")
print(df.describe())
# Out:
# Statistical Summary of the Dataset:
#               ROWID  State LGD Code  District LGD Code  \
# count  4.191946e+06    4.191946e+06       4.191946e+06
# mean   2.095974e+06    1.909219e+01       3.473938e+02
# std    1.210111e+06    1.059792e+01       2.055882e+02
# min    1.000000e+00    1.000000e+00       1.000000e+00
# 25%    1.047987e+06    8.000000e+00       1.200000e+02
# 50%    2.095974e+06    2.200000e+01       4.090000e+02
# 75%    3.143960e+06    2.800000e+01       5.210000e+02
# max    4.191946e+06    3.600000e+01       7.370000e+02
#
#        Minimum price for the commodity in the market  \
# count                                   4.191946e+06
# mean                                    2.945016e+03
# std                                     4.998278e+03
# min                                     0.000000e+00
# 25%                                     1.000000e+03
# 50%                                     1.800000e+03
# 75%                                     3.600000e+03
# ...

# %%
# Check the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#     ROWID Country  State LGD Code         State  District LGD Code  District  \
# 0   56811   India              22  Chhattisgarh                321   Purulia
# 1   68679   India              22  Chhattisgarh                321   Purulia
# 2   91860   India              22  Chhattisgarh                321   Purulia
# 3  133475   India              22  Chhattisgarh                321   Purulia
# 4  139356   India               7         Delhi                671  Shahdara
#
#     Market Name       Commodity Name Variety of commodities  \
# 0  Raghunathpur  Paddy(Dhan)(Common)                   Fine
# 1  Raghunathpur  Paddy(Dhan)(Common)                   Fine
# 2  Raghunathpur  Paddy(Dhan)(Common)                   Fine
# 3  Raghunathpur  Paddy(Dhan)(Common)                   Fine
# 4      Shahdara                Lemon                  Other
#
#   Grade standard of commodity  ...  Modal price for the commodity  \
# ...

# %%
import seaborn as sns

# Select relevant numeric columns
price_cols = ['Minimum price for the commodity in the market', 
              'Maximum price for the commodity in the market', 
              'Modal price for the commodity']

# Compute the correlation matrix
corr_matrix = df[price_cols].corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title('Correlation Matrix of Prices')
plt.show()
